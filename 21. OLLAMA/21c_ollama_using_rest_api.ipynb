# %% [markdown]
# # GENERATE USING OLLAMA LIBRARY

# %%
import ollama

response= ollama.generate(
    model="llama3.2:1b",
    prompt="Explain black holes simply"
)

print(response.response)
# Out:
# Black holes are a fundamental concept in astronomy, but I'll try to simplify it for you.
#
# **What is a Black Hole?**
#
# A black hole is a region in space where the gravitational pull is so strong that nothing, not even light, can escape. It's called a "black" hole because its gravity is so powerful that it warps the fabric of spacetime around it, making it invisible to us.
#
# **How are Black Holes Formed?**
#
# Black holes are formed when a massive star collapses in on itself and its gravity becomes so strong that it creates a singularity (a point with infinite density and zero volume). This singularity is surrounded by an event horizon, which marks the boundary of the black hole. Anything that crosses the event horizon is trapped by the black hole's gravity and cannot escape.
#
# **The Magic of Gravity**
#
# To understand why black holes are so strong, let's talk about gravity. According to Einstein's theory of general relativity, gravity is not a force that acts between objects, but rather a curvature of spacetime caused by massive objects. When a star collapses, its mass creates a massive gravitational field that warps the fabric of spacetime.
#
# **The Event Horizon**
#
# The event horizon is like a point of no return around a black hole. Once something crosses the event horizon, it's trapped and cannot escape. The gravity of the black hole becomes so strong that even light, which can travel at incredible speeds (up to 186,282 miles per second), cannot escape.
#
# **Visualizing Black Holes**
#
# Imagine spacetime as a fabric that gets warped and bent by massive objects. A black hole is like a cosmic singularity that warps spacetime in such a way that nothing can escape its gravitational pull. Think of it like a super-powerful vortex that sucks everything in, including light.
#
# **In a Nutshell**
#
# Black holes are regions of space where gravity is so strong that not even light can escape. They're formed when massive stars collapse in on themselves and create an event horizon that marks the boundary of the black hole. The gravity of the black hole warps spacetime, creating a cosmic singularity that traps everything inside.
#
# That's a basic explanation of black holes!

# %% [markdown]
# # GENERATE USING REST API

# %%
import requests
import json

url = "http://localhost:11434/api/generate"

payload = {
    "model": "llama3.2:1b",
    "prompt": "Explain black holes simply"
}


response = requests.post(url, json=payload)

# %%
for i in response.iter_lines(): #ollama sends multiple json lines
    print(i)
# Out:
# b'{"model":"llama3.2:1b","created_at":"2026-06-30T15:16:31.7781145Z","response":"Black","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-06-30T15:16:31.802372Z","response":" holes","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-06-30T15:16:31.8247378Z","response":" are","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-06-30T15:16:31.8473632Z","response":" really","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-06-30T15:16:31.869051Z","response":" interesting","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-06-30T15:16:31.88473Z","response":",","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-06-30T15:16:31.9037877Z","response":" but","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-06-30T15:16:31.9208119Z","response":" also","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-06-30T15:16:31.9389694Z","response":" a","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-06-30T15:16:31.9554824Z","response":" bit","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-06-30T15:16:31.9726889Z","response":" tricky","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-06-30T15:16:31.9876066Z","response":" to","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-06-30T15:16:32.0053935Z","response":" explain","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-06-30T15:16:32.0212999Z","response":".","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-06-30T15:16:32.0376962Z","response":" Here","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-06-30T15:16:32.0553929Z","response":"\'s","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-06-30T15:16:32.0719542Z","response":" a","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-06-30T15:16:32.084696Z","response":" simple","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-06-30T15:16:32.1004392Z","response":" explanation","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-06-30T15:16:32.1125682Z","response":":\\n\\n","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-06-30T15:16:32.1254964Z","response":"**","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-06-30T15:16:32.1368853Z","response":"What","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-06-30T15:16:32.1510258Z","response":" is","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-06-30T15:16:32.1673256Z","response":" a","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-06-30T15:16:32.1798701Z","response":" black","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-06-30T15:16:32.1925099Z","response":" hole","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-06-30T15:16:32.205645Z","response":"?","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-06-30T15:16:32.2174857Z","response":"**\\n\\n","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-06-30T15:16:32.234028Z","response":"A","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-06-30T15:16:32.2468592Z","response":" black","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-06-30T15:16:32.262407Z","response":" hole","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-06-30T15:16:32.2732645Z","response":" is","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-06-30T15:16:32.2859407Z","response":" a","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-06-30T15:16:32.302087Z","response":" region","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-06-30T15:16:32.3142544Z","response":" in","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-06-30T15:16:32.3303829Z","response":" space","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-06-30T15:16:32.3412292Z","response":" where","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-06-30T15:16
555,279,3776,14512,596,24128,382,334,29690,57277,14755,20349,527,27387,6302,430,3136,311,81613,14248,323,279,4689,586,27083,13,6104,814,649,387,4059,1481,16499,2785,398,6485,11,8830,872,32874,649,1520,603,15763,279,15400,8603,520,990,304,1057,15861,13],"total_duration":6639660000,"load_duration":270906400,"prompt_eval_count":30,"prompt_eval_duration":26888000,"eval_count":459,"eval_duration":6328571000}'

# %%
output= ""

for i in response.iter_lines():
    if i:
        data = json.loads(i.decode("utf-8"))
        if "response" in data:
            output+=data["response"]
        if data.get("done"):
            break


print(output)
# Out:
# Black holes are really interesting, but also a bit tricky to explain. Here's a simple explanation:
#
# **What is a black hole?**
#
# A black hole is a region in space where the gravitational pull is so strong that nothing, including light, can escape. It's like a super-powerful vacuum cleaner that sucks up everything around it.
#
# **How does it form?**
#
# Black holes are created when a massive star collapses in on itself and its gravity becomes so strong that it warps the fabric of space and time around it. Imagine a huge cloud of gas and dust collapsing into a tiny point, like a pinpoint dot. That's basically what happens to create a black hole.
#
# **What's so special about black holes?**
#
# Here are some key things about black holes:
#
# 1. **No light can escape**: As I mentioned earlier, not even light can escape from a black hole. This is why it's invisible.
# 2. **Gravity is extreme**: The gravity of a black hole is so strong that it warps space and time around it. Objects get pulled towards the center, where they get stretched out like rubber bands (this is called spaghettification).
# 3. **Time can be distorted**: Time can also be affected by the presence of a black hole. Time passes differently near a black hole, which means that time dilation occurs.
#
# **Some interesting facts about black holes**
#
# 1. **Black holes are not empty**: Despite what you might think, black holes are not completely empty. They contain gravity so strong that not even light can escape.
# 2. **Black holes come in different sizes**: There are three main types of black holes: stellar black holes (formed from stars), supermassive black holes (found at the centers of galaxies), and miniature black holes ( hypothetical, thought to be too small to exist).
# 3. **Black holes have a "event horizon"**: The point of no return around a black hole is called the event horizon. Once you cross this boundary, you're essentially trapped by the black hole's gravity.
#
# **Remember**
#
# Black holes are fascinating objects that continue to intrigue scientists and the general public alike. While they can be mind-bogglingly complex, understanding their basics can help us appreciate the incredible forces at work in our universe.

# %% [markdown]
# # LIST USING OLLAMA LIBRARY

# %%
import ollama

models = ollama.list()


models   # models with details of models.
# Out:
# ListResponse(models=[Model(model='qwen3:8b', modified_at=datetime.datetime(2026, 6, 30, 19, 57, 25, 139911, tzinfo=TzInfo(19800)), digest='500a1f067a9f782620b40bee6f7b0c89e17ae61f686b92c24933e4ca4b2b8b41', size=5225388164, details=ModelDetails(parent_model='', format='gguf', family='qwen3', families=['qwen3'], parameter_size='8.2B', quantization_level='Q4_K_M')), Model(model='llama3.2:1b', modified_at=datetime.datetime(2026, 6, 30, 17, 39, 52, 789121, tzinfo=TzInfo(19800)), digest='baf6a787fdffd633537aa2eb51cfd54cb93ff08e28040095462bb63daf552878', size=1321098329, details=ModelDetails(parent_model='', format='gguf', family='llama', families=['llama'], parameter_size='1.2B', quantization_level='Q8_0')), Model(model='gemma3:4b', modified_at=datetime.datetime(2026, 6, 30, 16, 37, 51, 511098, tzinfo=TzInfo(19800)), digest='a2af6cc3eb7fa8be8504abaf9b04e88f17a119ec3f04a3addf55f92841195f5a', size=3338801804, details=ModelDetails(parent_model='', format='gguf', family='gemma3', families=['gemma3'], parameter_size='4.3B', quantization_level='Q4_K_M')), Model(model='ministral-3:8b', modified_at=datetime.datetime(2026, 6, 30, 16, 34, 29, 189033, tzinfo=TzInfo(19800)), digest='1922accd5827ebe6829e536369195db25eaf664528dc66206d646ea3bb386b71', size=6022236616, details=ModelDetails(parent_model='', format='gguf', family='mistral3', families=['mistral3'], parameter_size='8.9B', quantization_level='Q4_K_M'))])

# %%
for model in models["models"]:  # iterate over models.
    print(model["model"])
# Out:
# qwen3:8b
# llama3.2:1b
# gemma3:4b
# ministral-3:8b

# %% [markdown]
# # LIST USING REST API

# %%
import requests

url = "http://localhost:11434/api/tags"

r = requests.get(url)
data = r.json() #extracting the JSON data from the HTTP response and converting it into a Python object


data  # entire data.
# Out:
# {'models': [{'name': 'qwen3:8b',
#    'model': 'qwen3:8b',
#    'modified_at': '2026-06-30T19:57:25.1399119+05:30',
#    'size': 5225388164,
#    'digest': '500a1f067a9f782620b40bee6f7b0c89e17ae61f686b92c24933e4ca4b2b8b41',
#    'details': {'parent_model': '',
#     'format': 'gguf',
#     'family': 'qwen3',
#     'families': ['qwen3'],
#     'parameter_size': '8.2B',
#     'quantization_level': 'Q4_K_M',
#     'context_length': 40960,
#     'embedding_length': 4096},
#    'capabilities': ['completion', 'tools', 'thinking']},
#   {'name': 'llama3.2:1b',
#    'model': 'llama3.2:1b',
#    'modified_at': '2026-06-30T17:39:52.7891219+05:30',
#    'size': 1321098329,
#    'digest': 'baf6a787fdffd633537aa2eb51cfd54cb93ff08e28040095462bb63daf552878',
#    'details': {'parent_model': '',
#     'format': 'gguf',
#     'family': 'llama',
#     'families': ['llama'],
#     'parameter_size': '1.2B',
#     'quantization_level': 'Q8_0',
#     'context_length': 131072,
#     'embedding_length': 2048},
#    'capabilities': ['completion', 'tools']},
#   {'name': 'gemma3:4b',
#    'model': 'gemma3:4b',
#    'modified_at': '2026-06-30T16:37:51.5110986+05:30',
#    'size': 3338801804,
#    'digest': 'a2af6cc3eb7fa8be8504abaf9b04e88f17a119ec3f04a3addf55f92841195f5a',
#    'details': {'parent_model': '',
#     'format': 'gguf',
#     'family': 'gemma3',
#     'families': ['gemma3'],
#     'parameter_size': '4.3B',
#     'quantization_level': 'Q4_K_M'},
#    'capabilities': ['completion']},
#   {'name': 'ministral-3:8b',
#    'model': 'ministral-3:8b',
#    'modified_at': '2026-06-30T16:34:29.1890333+05:30',
#    'size': 6022236616,
#    'digest': '1922accd5827ebe6829e536369195db25eaf664528dc66206d646ea3bb386b71',
#    'details': {'parent_model': '',
#     'format': 'gguf',
#     'family': 'mistral3',
#     'families': ['mistral3'],
#     'parameter_size': '8.9B',
#     'quantization_level': 'Q4_K_M',
#     'context_length': 262144,
#     'embedding_length': 4096},
#    'capabilities': ['vision', 'completion', 'tools']}]}

# %%
for model in data["models"]:
    print(model["name"])
# Out:
# qwen3:8b
# llama3.2:1b
# gemma3:4b
# ministral-3:8b
